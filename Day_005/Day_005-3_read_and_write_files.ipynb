# %% [markdown]
# ## 讀取圖片
# 常見的套件:
# 1. skimage
# 2. PIL
# 3. OpenCV

# %% [markdown]
# # [教學目標]
# - 示範其他的讀圖檔方式

# %% [markdown]
# # [範例重點]
# - 用 skimage.io 讀取圖檔 (In[2], Out[2])
# - 用 PIL.Image 讀取圖檔 (In[3], Out[3])
# - 用 OpenCV 讀取圖檔 (In[4], Out[4])

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# %conda install scikit-image
# %conda install Pillow
# %conda install OpenCV
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.10.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/op_vrijheid/opt/anaconda3/envs/Machine_Learning
#
#   added / updated specs:
#     - scikit-image
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     scipy-1.11.3               |  py310hdb2ea58_0        20.7 MB
#     ------------------------------------------------------------
#                                            Total:        20.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   aom                pkgs/main/osx-64::aom-3.6.0-hcec6c5f_0 None
#   blosc              pkgs/main/osx-64::blosc-1.21.3-hcec6c5f_0 None
#   brunsli            pkgs/main/osx-64::brunsli-0.1-h23ab428_0 None
#   c-ares             pkgs/main/osx-64::c-ares-1.19.1-h6c40b1e_0 None
#   cfitsio            pkgs/main/osx-64::cfitsio-3.470-hbd21bf8_7 None
#   charls             pkgs/main/osx-64::charls-2.2.0-h23ab428_0 None
#   cytoolz            pkgs/main/osx-64::cytoolz-0.12.0-py310hca72f7f_0 None
#   dask-core          pkgs/main/osx-64::dask-core-2023.6.0-py310hecd8cb5_0 None
#   dav1d              pkgs/main/osx-64::dav1d-1.2.1-h6c40b1e_0 None
#   fsspec             pkgs/main/osx-64::fsspec-2023.9.2-py310hecd8cb5_0 None
#   imagecodecs        pkgs/main/osx-64::imagecodecs-2023.1.23-py310hd1bf5dc_0 None
#   imageio            pkgs/main/osx-64::imageio-2.31.4-py310hecd8cb5_0 None
#   jxrlib             pkgs/main/osx-64::jxrlib-1.1-haf1e3a3_2 None
#   lazy_loader        pkgs/main/osx-64::lazy_loader-0.3-py310hecd8cb5_0 None
#   libaec             pkgs/main/osx-64::libaec-1.0.4-hb1e8313_1 None
#   libavif            pkgs/main/osx-64::libavif-0.11.1-h6c40b1e_0 None
#   libcurl            pkgs/main/osx-64::libcurl-8.2.1-ha585b31_0 None
#   libev              pkgs/main/osx-64::libev-4.33-h9ed2024_1 None
#   libgfortran        pkgs/main/osx-64::libgfortran-5.0.0-11_3_0_hecd8cb5_28 None
#   libgfortran5       pkgs/main/osx-64::libgfortran5-11.3.0-h9dfd629_28 None
#   libnghttp2         pkgs/main/osx-64::libnghttp2-1.52.0-h1c88b7d_1 None
#   libssh2            pkgs/main/osx-64::libssh2-1.10.0-hdb2fb19_2 None
#   libzopfli          pkgs/main/osx-64::libzopfli-1.0.3-hb1e8313_0 None
#   locket             pkgs/main/osx-64::locket-1.0.0-py310hecd8cb5_0 None
#   networkx           pkgs/main/osx-64::networkx-3.1-py310hecd8cb5_0 None
#   openjpeg           pkgs/main/osx-64::openjpeg-2.4.0-h66ea3da_0 None
#   partd              pkgs/main/osx-64::partd-1.4.1-py310hecd8cb5_0 None
#   pywavelets         pkgs/main/osx-64::pywavelets-1.4.1-py310h6c40b1e_0 None
#   scikit-image       pkgs/main/osx-64::scikit-image-0.20.0-py310hcec6c5f_0 None
#   scipy              pkgs/main/osx-64::scipy-1.11.3-py310hdb2ea58_0 None
#   snappy             pkgs/main/osx-64::snappy-1.1.9-he9d5cce_0 None
#   tifffile           pkgs/main/osx-64::tifffile-2023.4.12-py310hecd8cb5_0 None
#   toolz              pkgs/main/osx-64::toolz-0.12.0-py310hecd8cb5_0 None
#   zfp                pkgs/main/osx-64::zfp-1.0.0-hcec6c5f_0 None
#
#
#
# Downloading and Extracting Packages
# scipy-1.11.3         | 20.7 MB   | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.10.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.10.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/op_vrijheid/opt/anaconda3/envs/Machine_Learning
#
#   added / updated specs:
#     - opencv
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ffmpeg-4.2.2               |       h97e5cf8_0        22.9 MB
#     scipy-1.11.3               |  py310ha516a68_0        20.7 MB
#     ------------------------------------------------------------
#                                            Total:        43.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   cairo              pkgs/main/osx-64::cairo-1.16.0-h3ce6f7e_5 None
#   eigen              pkgs/main/osx-64::eigen-3.3.7-haf03e11_1 None
#   expat              pkgs/main/osx-64::expat-2.5.0-hcec6c5f_0 None
#   ffmpeg             pkgs/main/osx-64::ffmpeg-4.2.2-h97e5cf8_0 None
#   fontconfig         pkgs/main/osx-64::fontconfig-2.14.1-hedf32ac_1 None
#   gmp                pkgs/main/osx-64::gmp-6.2.1-he9d5cce_3 None
#   gnutls             pkgs/main/osx-64::gnutls-3.6.15-hed9c0bf_0 None
#   graphite2          pkgs/main/osx-64::graphite2-1.3.14-he9d5cce_1 None
#   harfbuzz           pkgs/main/osx-64::harfbuzz-4.3.0-hffc734d_1 None
#   hdf5               pkgs/main/osx-64::hdf5-1.12.1-h2b2ad87_2 None
#   lame               pkgs/main/osx-64::lame-3.100-h1de35cc_0 None
#   libidn2            pkgs/main/osx-64::libidn2-2.3.4-h6c40b1e_0 None
#   libopenblas        pkgs/main/osx-64::libopenblas-0.3.21-h54e7dc3_0 None
#   libopus            pkgs/main/osx-64::libopus-1.3.1-h1de35cc_0 None
#   libtasn1           pkgs/main/osx-64::libtasn1-4.19.0-h6c40b1e_0 None
#   libunistring       pkgs/main/osx-64::libunistring-0.9.10-h9ed2024_0 None
#   libvpx             pkgs/main/osx-64::libvpx-1.7.0-h378b8a2_0 None
#   nettle             pkgs/main/osx-64::nettle-3.7.3-h230ac6f_1 None
#   opencv             pkgs/main/osx-64::opencv-4.6.0-py310h9991a6c_5 None
#   openh264           pkgs/main/osx-64::openh264-2.1.1-h8346a28_0 None
#   pixman             pkgs/main/osx-64::pixman-0.40.0-h9ed2024_1 None
#   x264               pkgs/main/osx-64::x264-1!157.20191217-h1de35cc_0 None
#
# The following packages will be REMOVED:
#
#   mkl_fft-1.3.6-py310h3ea8b11_1
#   mkl_random-1.2.2-py310h3ea8b11_1
#
# The following packages will be UPDATED:
#
#   blas                                              1.0-mkl --> 1.0-openblas None
#   numexpr                             2.8.4-py310h827a554_1 --> 2.8.7-py310hf6dca73_0 None
#   numpy                              1.25.2-py310h827a554_0 --> 1.26.0-py310hf6dca73_0 None
#   numpy-base                         1.25.2-py310ha186be2_0 --> 1.26.0-py310hd8f4981_0 None
#
# The following packages will be DOWNGRADED:
#
#   scipy                              1.11.3-py310hdb2ea58_0 --> 1.11.3-py310ha516a68_0 None
#
#
#
# Downloading and Extracting Packages
# scipy-1.11.3         | 20.7 MB   | ##################################### | 100%
# ffmpeg-4.2.2         | 22.9 MB   | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import skimage.io as skio
img1 = skio.imread('example.jpg')
plt.imshow(img1)
plt.show()

# %%
from PIL import Image
img2 = Image.open('example.jpg') #這時候還是 PIL object
img2 = np.array(img2)
plt.imshow(img2)
plt.show()

# %%
import cv2
img3 = cv2.imread('example.jpg')
plt.imshow(img3)
plt.show()

img3 = cv2.cvtColor(img3, cv2.COLOR_BGR2RGB)
plt.imshow(img3)
plt.show()

# %% [markdown]
# ### 比較三種開圖方式的時間 - 比較讀取 1000 次

# %%
N_times = 1000

# %%
# %%timeit
im = np.array([skio.imread('example.jpg') for _ in range(N_times)])
# Out:
# 892 ms ± 18.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
im = np.array([np.array(Image.open('example.jpg')) for _ in range(N_times)])
# Out:
# 715 ms ± 15 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
im = np.array([cv2.cvtColor(cv2.imread('example.jpg'), cv2.COLOR_BGR2RGB) for _ in range(N_times)])
# Out:
# 643 ms ± 24.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## 將影像存成 mat

# %%
import scipy.io as sio
sio.savemat(file_name='example.mat', mdict={'img': img1})

# %%
mat_arr = sio.loadmat('example.mat')
print(mat_arr.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'img'])

# %%
mat_arr = mat_arr['img']
print(mat_arr.shape)
# Out:
# (183, 275, 3)

# %%
plt.imshow(mat_arr)
plt.show()

# %% [markdown]
# # 練習時間
#
# ## 1-1 讀取 txt 檔
# * 請讀取 [text file](https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt)
# * 懶人複製連結: https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt
#
# ## 1-2 將所提供的 txt 轉成 pandas dataframe
#
# ## 2. 從所提供的 txt 中的連結讀取圖片，請讀取上面 data frame 中的前 5 張圖片
